# %% [markdown]
# # Data Visualization Notebook

# %% [markdown]
# <font color='black'><b>Welcome to the DVN, the Data Visualization Notebook. In this Notebook, you can find the best handpicked graphs that best visualizes our data sets. In this Notebook you will find yourself to have an easy user experience while getting your own customized graphs. This Notebook has Variety of graphs already made and available to your use. Bellow is some of the graphs that are currently inside this notebook. In the near future, more graphs and options will be added, so look forward to those as well. If you have any suggestions for any graphs or options
#
# please email: "atoghani1623@student.whatcom.edu".</b></font>
#
# By: Ali Toghani

# %% [markdown]
# ## MENU

# %%
jupyter labextension install @jupyterlab/debugger
# Out:
#   File "<ipython-input-2-6646c2517c39>", line 1
#     @jupyterlab/debugger
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# Please Navigate in bellow in this notebook to view your options. Each option is independent of its own and will not be related to each other.

# %% [markdown]
# <b>Option 1: HeatMaps (Hexagon HeatMap) of a single data </b>
#
# <b>Option 2: HeatMaps (Hexagon HeatMap) of multiple data </b>
#
# <b>Option 3: 3D ScatterPlot of multiple data </b>

# %% [markdown]
# ## Option 1:
# #### please make sure to run all cells ( you can do "shift + Enter" to run them cell by cell )

# %%
## Please make sure to run this cell, This is importations for this option in the document. 
# %pylab inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Please place the file name exactly using the .csv bellow between r'here'. This will be your original csv file with all your data.

# %%
FileName = r'ogdseveritylabeled.csv'

# %% [markdown]
# You can uncomment intial_data.head() to confirm that your data has been imported correctly. The head method is showing the first 5 data rows of your data set that has been imported. Please double check that the correct data has been imported to limit any errors.

# %%
initial_data = pd.read_csv(FileName)
## initial_data.head()
## you can uncomment the line above to double check your table

# %% [markdown]
# Please insert the 2 columns names in which you like to create your HeatMap with. Replace them with example

# %%
FirstSet = 'major_axis_length'
SecondSet = 'minor_axis_length'

# %% [markdown]
# Creating a data set and sorting the values

# %%
data = initial_data[[FirstSet, SecondSet]]
data.sort_values(by=[FirstSet])
data_small = data

# %% [markdown]
# Because outliers can make the graph to look very small, this code will remove it. You can skip this cell if you do not want to remove any outliers, the graph could not be as clear as it would be without it.¶

# %%
major_median = data[FirstSet].median()
major_stds =  data[SecondSet].std()
cut_off_high = major_median + 3 * major_stds
cut_off_low= major_median - 3 * major_stds
data_small = data[data.major_axis_length <= cut_off_high]
data_small = data_small[data_small.major_axis_length >= cut_off_low]

# %% [markdown]
# ### The Graph
# <b> In the next line, you can try and customize the way your graph behaves.</b>
#
# <b><font color=#32a852>Kind</font></b> = Hex : the type of this graph can be changed, but for more of a organization you can also look at the options above and going to that code instead.
#
# We have:
#
# 1. hex
#
# 2. scatter
#
# 3. kde
#
# 4. hist
#
# 5. reg
#
# 6. resid
#
# <b><font color=#32a852>height</font></b> = the example is showing the height of 20, but you can change this based on the size you would like your graph to be shown.
#
# <b><font color=#32a852>x and y</font></b> = x and y is the 2 columns from your data set that you are creating your heatmap for. the default format has been set for x for firstset and y for secondset, but you can just change firstset and secondset with each other.
#
# <b><font color=#32a852>color</font></b> = This color can be either Hex color such as "#32a852" or "red"

# %%
sns.jointplot(data=data_small, x=FirstSet, y=SecondSet, kind='kde' ,height= 20,color="#32a852")
plt.show()

# %% [markdown]
# ## Option 2:
# #### please make sure to run all cells ( you can do "shift + Enter" to run them cell by cell )

# %%
## Please make sure to run this cell, This is importations for this option in the document. 
# %pylab inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Please place the file name exactly using the .csv bellow between r'here'. This will be your original csv file with all your data.

# %%
FileName = r'06_04_2021_allim_features_maxint.csv'

# %% [markdown]
# You can uncomment intial_data.head() to confirm that your data has been imported correctly. The head method is showing the first 5 data rows of your data set that has been imported. Please double check that the correct data has been imported to limit any errors.

# %%
initial_data = pd.read_csv(FileName)
## initial_data.head()
## you can uncomment the line above to double check your table

# %% [markdown]
# Please insert the 2 columns names in which you like to create your HeatMap with. Replace them with example

# %%
FirstSet = 'major_axis_length'
SecondSet = 'minor_axis_length'

# %% [markdown]
# Please put the name of the category that you would like to seperate to show the visualization of. An example of this could be genders or different ID pictures.

# %%
CategroyName = 'sample_id'

# %%
initial_data["sample_id"].unique()
# Out:
# array([2347, 2205, 2441, 2346, 2206, 2413, 2317, 2414, 2313, 2306, 2312,
#        2316, 2412], dtype=int64)

# %% [markdown]
# This next cell is going to create different csv files based on the categories chosen. For example if gender was chosen, there will be a 2 new csv files created which would be named female and male.

# %%
import csv

Category = []

with open(FileName) as fin:    
    csvin = csv.DictReader(fin)
    # Category -> open file lookup
    outputs = {}
    for row in csvin:
        cat = row[CategroyName]
        # Open a new file and write the header
        if cat not in outputs:
            Category.append(cat)
            fout = open('{}.csv'.format(cat), 'w')
            dw = csv.DictWriter(fout, fieldnames=csvin.fieldnames)
            dw.writeheader()
            outputs[cat] = fout, dw
        # Always write the row
        outputs[cat][1].writerow(row)
    # Close all the files
    for fout, _ in outputs.values():
        fout.close()
        
Category.pop(len(Category)-1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-042399e962d2> in <module>
#       8     outputs = {}
#       9     for row in csvin:
# ---> 10         cat = row[CategroyName]
#      11         # Open a new file and write the header
#      12         if cat not in outputs:
#
# KeyError: 'sample_id'

# %% [markdown]
# #### Please enter the 2 columns in which you like to create your HeatMap with, this will be your X and Y axis.

# %%
FirstSet ='major_axis_length'
SecondSet =  'minor_axis_length'

# %%
for r in Category:
    x = r + ".csv"
    initial_data = pd.read_csv(x)
    initial_data.head()

    dataGroup = initial_data[[FirstSet, SecondSet]]
    dataGroup.sort_values(by=[FirstSet])

    FirstSet_median =  dataGroup [FirstSet].median()
    FirstSet_stds   =  dataGroup [FirstSet].std()

    cut_off_high = FirstSet_median + 3 * FirstSet_stds
    cut_off_low  = FirstSet_median - 3 * FirstSet_stds

    data_small = dataGroup [dataGroup.major_axis_length <= cut_off_high]
    data_small = data_small [data_small.major_axis_length >= cut_off_low]
    
    p = sns.jointplot(data=data_small, x=FirstSet, y=SecondSet, kind='hex' ,height= 5)
    p.fig.suptitle(r)
    plt.show()

# %% [markdown]
# ## Option 3:
# #### please make sure to run all cells ( you can do "shift + Enter" to run them cell by cell )|

# %%
import csv

Category = []

with open(FileName) as fin:    
    csvin = csv.DictReader(fin)
    # Category -> open file lookup
    outputs = {}
    for row in csvin:
        cat = row[CategroyName]
        # Open a new file and write the header
        if cat not in outputs:
            Category.append(cat)
            fout = open('{}.csv'.format(cat), 'w')
            dw = csv.DictWriter(fout, fieldnames=csvin.fieldnames)
            dw.writeheader()
            outputs[cat] = fout, dw
        # Always write the row
        outputs[cat][1].writerow(row)
    # Close all the files
    for fout, _ in outputs.values():
        fout.close()
        
Category.pop(len(Category)-1)
# Out:
# '2412'

# %%
# %matplotlib notebook

fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig)
u = 0



size = len(Category)
color_pal = sns.color_palette("colorblind", size).as_hex()

for r in Category:
    xr = r+ ".csv"
    df = pd.read_csv(xr)
     
    # Comment the lines bellow if you would like to keep their outliers. 
    dataGroup = df[[FirstSet, SecondSet]]
    dataGroup.sort_values(by=[FirstSet])

    FirstSet_median =  dataGroup [FirstSet].median()
    FirstSet_stds   =  dataGroup [FirstSet].std()

    cut_off_high = FirstSet_median + 3 * FirstSet_stds
    cut_off_low  = FirstSet_median - 3 * FirstSet_stds

    data_small = dataGroup [dataGroup.major_axis_length <= cut_off_high]
    data_small = data_small [data_small.major_axis_length >= cut_off_low]
    
    
    x = data_small[FirstSet]
    y = data_small[SecondSet]
    sc = ax.scatter(x, y, u, c=color_pal[u], marker='.', cmap=cm, alpha=0.5)
    ax.set(zticks=range(len(Category)), zticklabels=Category)
    u = u + 1
    
    
legendc = plt.legend(Category, loc ="lower right")

ax.add_artist(legendc)
ax.set_xlabel(FirstSet)
ax.set_ylabel(SecondSet)
ax.set_zlabel(CategroyName)
# Out:
# <img src="data:image/png;base64,..." width="720">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-d125b3dbe14a> in <module>
#       2
#       3 fig = plt.figure(figsize=(10,10))
# ----> 4 ax = Axes3D(fig)
#       5 u = 0
#       6
#
# NameError: name 'Axes3D' is not defined
